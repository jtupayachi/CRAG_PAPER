# %%
# Importing necessary libraries
import pandas as pd

# Defining the file path
file_path = '/finetuning/train-00000-of-00001-5e7cb295b9cff0bf.parquet'

# Reading the parquet file
data = pd.read_parquet(file_path)

# %%
data=data.iloc[:1]

# %% [markdown]
# # CRD:

# %%
# Define the data for the objects with added text for description
descriptions = [
    """
    Check if Knoxville is an hub that belong to the endpoint CRD [output sh code].
    """
    """
    Execute the query curl -X GET https://portal.recoil.ise.utk.edu/api/crd/?crd_dms=Knoxville this queries the attributes of the location <location name>? [output sh code].
    """,
    """
    Check if Road is a transportation mode that belongs to the endpoint CRD [output sh code].
    """,
    """
    Execute the query curl -X GET https://portal.recoil.ise.utk.edu/api/crd/?crd_dms=Knxoville&crd_mode=road this queries the attributes of the Hub on the basis of the Knoxville and mode road? [output sh code].
    """,
    """
    Check if Road represents a transportation mode that belongs to the endpoint LCA [output sh code].
    """,
    """
    Check if Long_Haul Trucks represents a vehicle type that belongs to the endpoint LCA [output sh code].
    """,
    """
    Execute the query curl -X GET https://portal.recoil.ise.utk.edu/api/lca/?lca_vehicle_type=Long_Haul%20Trucks&lca_transportation_mode=Road this queries the attributes of the life cycle analysis based on vehicle type Long Haul Trucks and transportation mode Road? [output sh code].
    """,
    """
    Check if Conventional and LS Diesel represents a fuel type that belongs to the enpoint LCA [output sh code].
    """,
    """
    Execute the query curl -X GET https://portal.recoil.ise.utk.edu/api/lca/?lca_vehicle_type=Long_Haul%20Trucks%20&lca_transportation_mode=Road&lca_fuel_type=Conventional+and+LS+Diesel this queries the attributes of the life cycle analysis based on vehicle type Long Haul Trucks, transportation mode Road and fuel type Conventional and LS Diesel? [output sh code]. 
    """,
    """
    Use the output and multiply the [{"id":1,"lca_vehicle_type":"Long_Haul Trucks ","lca_transportation_mode":"Road","lca_fuel_type":"Conventional and LS Diesel","lca_co_2_emission":1583.0492996398614,"lca_emission_unit":"g/miles"},{"id":2,"lca_vehicle_type":"Long_Haul Trucks ","lca_transportation_mode":"Road","lca_fuel_type":"Any","lca_co_2_emission":1317.904931562858,"lca_emission_unit":"g/miles"},{"id":3,"lca_vehicle_type":"Long_Haul Trucks ","lca_transportation_mode":"Road","lca_fuel_type":"LNG","lca_co_2_emission":1284.5732130670176,"lca_emission_unit":"g/miles"},{"id":4,"lca_vehicle_type":"Long_Haul Trucks ","lca_transportation_mode":"Road","lca_fuel_type":"Electricity","lca_co_2_emission":1171.8959741252,"lca_emission_unit":"g/miles"}] by 100 miles considering the different units [output sh code].
    """
    
        
]

# Define the process structure once since it's shared by both
process_structure = [
    
    
""" 
#!/bin/bash
# Define the search term and API endpoint
SEARCH_QUERY="Knoxville"
ENDPOINT_URL="https://portal.recoil.ise.utk.edu/api/crd/crd_dms/"

# Query the API and check for response and partial match in one go
if response=$(curl -s "$ENDPOINT_URL") && \
   [[ -n "$response" ]] && \
   echo "$response" | jq -e --arg query "$SEARCH_QUERY" '[.[] | select(gsub(" "; "") == gsub(" "; "") | $query)] | any' >/dev/null; then
  echo "$SEARCH_QUERY is a match."
else
  echo "Error: No valid response or $SEARCH_QUERY is not a match."
fi
""",

    
"""
#!/bin/bash
SEARCH_QUERY="Knoxville"

# URL-encode the search query using printf
ENCODED_SEARCH_QUERY=$(printf '%s\n' "$SEARCH_QUERY" | jq -sRr @uri)

response=$(curl -s "https://portal.recoil.ise.utk.edu/api/crd/?crd_dms=${SEARCH_QUERY}")
echo "$response" 
""",
    


    
"""
#!/bin/bash
# Define the API URL and transportation mode to check
ENDPOINT_URL="https://portal.recoil.ise.utk.edu/api/crd/crd_mode/"
SEARCH_QUERY="road"

# Query the API and check for response and partial match in one go
if response=$(curl -s "$ENDPOINT_URL") && \
   [[ -n "$response" ]] && \
   echo "$response" | jq -e --arg query "$SEARCH_QUERY" '[.[] | select(gsub(" "; "") == gsub(" "; "") | $query)] | any' >/dev/null; then
  echo "$SEARCH_QUERY is a match."
else
  echo "Error: No valid response or $SEARCH_QUERY is not a match."
fi
""",


"""
#!/bin/bash
SEARCH_QUERY="road"
SEARCH_QUERY2="Knoxville"

# URL-encode the search query using printf
ENCODED_SEARCH_QUERY=$(printf '%s\n' "$SEARCH_QUERY" | jq -sRr @uri)
ENCODED_SEARCH_QUERY2=$(printf '%s\n' "$SEARCH_QUERY2" | jq -sRr @uri)

# Make sure to use the encoded search query in the curl request
response=$(curl -s "https://portal.recoil.ise.utk.edu/api/crd/?crd_dms=${ENCODED_SEARCH_QUERY2}&crd_dms_mode=${ENCODED_SEARCH_QUERY}")
echo "$response"
""",


    
"""
#!/bin/bash
# Define the API URL and transportation mode to check
ENDPOINT_URL="https://portal.recoil.ise.utk.edu/api/lca/transportation_mode/"
SEARCH_QUERY="Road"

# Query the API and check for response and partial match
if response=$(curl -s "$ENDPOINT_URL") && \
   [[ -n "$response" ]] && \
   echo "$response" | jq -e --arg query "$SEARCH_QUERY" '[.[] | select(gsub(" "; "") == gsub(" "; "") | $query)] | any' >/dev/null; then
  echo "$SEARCH_QUERY is a transportation mode."
else
  echo "Error: No valid response or $SEARCH_QUERY is not a match.. Please select a different mode."
fi
""",


    
"""
#!/bin/bash
# Define the API URL and vehicle type to check
ENDPOINT_URL="https://portal.recoil.ise.utk.edu/api/lca/vehicle_type/"
SEARCH_QUERY="Long_Haul Trucks"

# Query the API and check for response and match
if response=$(curl -s "$ENDPOINT_URL") && \
   [[ -n "$response" ]] && \
   echo "$response" | jq -e --arg query "$SEARCH_QUERY" '[.[] | select(gsub(" "; "") == gsub(" "; "") | $query)] | any' >/dev/null; then
  echo "$SEARCH_QUERY is a match."
else
  echo "Error: No valid response or $SEARCH_QUERY is not a vehicle type."
fi
""",
 
    
"""
#!/bin/bash
SEARCH_QUERY="Long_Haul Trucks"
SEARCH_QUERY2="Road"

# URL-encode the parameters using printf
ENCODED_SEARCH_QUERY=$(printf '%s\n' "$SEARCH_QUERY" | jq -sRr @uri)
ENCODED_SEARCH_QUERY2=$(printf '%s\n' "$SEARCH_QUERY2" | jq -sRr @uri)

# Use double quotes to allow variable expansion
response=$(curl -s "https://portal.recoil.ise.utk.edu/api/lca/?lca_vehicle_type=${ENCODED_SEARCH_QUERY}&lca_transportation_mode=${ENCODED_SEARCH_QUERY2}")
echo "$response"
""",



"""
#!/bin/bash
# Define the API URL and search term to check
ENDPOINT_URL="https://portal.recoil.ise.utk.edu/api/lca/fuel_type/"
SEARCH_QUERY="Conventional and LS Diesel"

# Query the API and check for response and match
if response=$(curl -s "$ENDPOINT_URL") && \
   [[ -n "$response" ]] && \
   echo "$response" | jq -e --arg query "$SEARCH_QUERY" '[.[] | select(gsub(" "; "") == gsub(" "; "") | $query)] | any' >/dev/null; then
  echo "$SEARCH_QUERY is a fuel type."
else
  echo "Error: No valid response or $SEARCH_QUERY is not a match type."
fi
""",



    
"""
#!/bin/bash
SEARCH_QUERY="Long_Haul Trucks"
SEARCH_QUERY2="Road"
SEARCH_QUERY3="Conventional and LS Diesel"

# URL-encode the parameters using printf
ENCODED_SEARCH_QUERY=$(printf '%s\n' "$SEARCH_QUERY" | jq -sRr @uri)
ENCODED_SEARCH_QUERY2=$(printf '%s\n' "$SEARCH_QUERY2" | jq -sRr @uri)
ENCODED_SEARCH_QUERY3=$(printf '%s\n' "$SEARCH_QUERY3" | jq -sRr @uri)

# Use double quotes for variable expansion in the URL
response=$(curl -s "https://portal.recoil.ise.utk.edu/api/lca/?lca_vehicle_type=${ENCODED_SEARCH_QUERY}&lca_transportation_mode=${ENCODED_SEARCH_QUERY2}&lca_fuel_type=${ENCODED_SEARCH_QUERY3}")
echo "$response"
""",


"""
#!/bin/sh

# JSON input
JSON='[
    {"id":1,"lca_vehicle_type":"Long_Haul Trucks","lca_transportation_mode":"Road","lca_fuel_type":"Conventional and LS Diesel","lca_co_2_emission":1583.05,"lca_emission_unit":"g/miles"},
    {"id":2,"lca_vehicle_type":"Long_Haul Trucks","lca_transportation_mode":"Road","lca_fuel_type":"Any","lca_co_2_emission":1317.90,"lca_emission_unit":"g/miles"},
    {"id":3,"lca_vehicle_type":"Long_Haul Trucks","lca_transportation_mode":"Road","lca_fuel_type":"LNG","lca_co_2_emission":1284.57,"lca_emission_unit":"g/miles"},
    {"id":4,"lca_vehicle_type":"Long_Haul Trucks","lca_transportation_mode":"Road","lca_fuel_type":"Electricity","lca_co_2_emission":1171.90,"lca_emission_unit":"g/miles"}
]'
# Distance to calculate emissions for
DISTANCE=900

# Process each JSON object
echo "$JSON" | jq -c '.[]' | while read -r item; do
    # Extract CO2 emission
    co2_emission=$(echo "$item" | jq -r '.lca_co_2_emission')

    # Calculate total emissions
    total_emission=$(echo "$co2_emission * $DISTANCE" | bc)

    # Print total CO2 emissions
    echo "$total_emission"
done
    """
                    ]


# List to hold the structured object data
bank_renege1 = []

# Loop over the descriptions to create the object list
for ds,ps in zip(descriptions,process_structure):
    obj = {
        "instruction": "If you are an expert in sh script and curl query creation, please generate the logic and queries needed to answer the following question.",
        "input": ds,
        "output": ps
    }
    bank_renege1.append(obj)

# Print or use the list of objects
print(bank_renege1)
# Out:
# [{'instruction': 'If you are an expert in sh script and curl query creation, please generate the logic and queries needed to answer the following question.', 'input': '\n    Check if Knoxville is an hub that belong to the endpoint CRD [output sh code].\n    \n    Execute the query curl -X GET https://portal.recoil.ise.utk.edu/api/crd/?crd_dms=Knoxville this queries the attributes of the location <location name>? [output sh code].\n    ', 'output': ' \n#!/bin/bash\n\n# Query the API and store the response\nresponse=$(curl -s "https://portal.recoil.ise.utk.edu/api/crd/crd_dms/")\n\n# Check if the response is empty\nif [[ -z "$response" ]]; then\n  echo "Error: No response from the API."\n  exit 1\nfi\n# Check if the response is a valid JSON array\nif echo "$response" | jq -e . >/dev/null 2>&1; then\n  # Check if "Knoxville" is present in the response array\n  if echo "$response" | jq -e \'index("Knoxville")\' >/dev/null 2>&1; then\n    echo "Knoxville is an origin hub."\n  else\n    ec
# ...

# %%
# Define the data for the objects with added text for description
descriptions = [
    """
    Check if Knoxville is an hub that belong to the endpoint CRD [output sh code].
    """
    """
    Execute the query curl -X GET https://portal.recoil.ise.utk.edu/api/crd/?crd_dms=Knoxville this queries the attributes of the location <location name>? [output sh code].
    """,
    """
    Check if Road is a transportation mode that belongs to the endpoint CRD [output sh code].
    """,
    """
    Execute the query curl -X GET https://portal.recoil.ise.utk.edu/api/crd/?crd_dms=Knxoville&crd_mode=road this queries the attributes of the Hub on the basis of the Knoxville and mode road? [output sh code].
    """,
    """
    Check if Road represents a transportation mode that belongs to the endpoint LCA [output sh code].
    """,
    """
    Check if Long_Haul Trucks represents a vehicle type that belongs to the endpoint LCA [output sh code].
    """,
    """
    Execute the query curl -X GET https://portal.recoil.ise.utk.edu/api/lca/?lca_vehicle_type=Long_Haul%20Trucks&lca_transportation_mode=Road this queries the attributes of the life cycle analysis based on vehicle type Long Haul Trucks and transportation mode Road? [output sh code].
    """,
    """
    Check if Conventional and LS Diesel represents a fuel type that belongs to the enpoint LCA [output sh code].
    """,
    """
    Execute the query curl -X GET https://portal.recoil.ise.utk.edu/api/lca/?lca_vehicle_type=Long_Haul%20Trucks%20&lca_transportation_mode=Road&lca_fuel_type=Conventional+and+LS+Diesel this queries the attributes of the life cycle analysis based on vehicle type Long Haul Trucks, transportation mode Road and fuel type Conventional and LS Diesel? [output sh code]. 
    """,
    """
    Use the output and multiply the [{"id":1,"lca_vehicle_type":"Long_Haul Trucks ","lca_transportation_mode":"Road","lca_fuel_type":"Conventional and LS Diesel","lca_co_2_emission":1583.0492996398614,"lca_emission_unit":"g/miles"},{"id":2,"lca_vehicle_type":"Long_Haul Trucks ","lca_transportation_mode":"Road","lca_fuel_type":"Any","lca_co_2_emission":1317.904931562858,"lca_emission_unit":"g/miles"},{"id":3,"lca_vehicle_type":"Long_Haul Trucks ","lca_transportation_mode":"Road","lca_fuel_type":"LNG","lca_co_2_emission":1284.5732130670176,"lca_emission_unit":"g/miles"},{"id":4,"lca_vehicle_type":"Long_Haul Trucks ","lca_transportation_mode":"Road","lca_fuel_type":"Electricity","lca_co_2_emission":1171.8959741252,"lca_emission_unit":"g/miles"}] by 100 miles considering the different units [output sh code].
    """
    
        
]

# Define the process structure once since it's shared by both
process_structure = [
    
    
""" 
#!/bin/bash
# Define the search term and API endpoint
SEARCH_QUERY="Knoxville"
ENDPOINT_URL="https://portal.recoil.ise.utk.edu/api/crd/crd_dms/"

# Query the API and check for response and partial match in one go
if response=$(curl -s "$ENDPOINT_URL") && \
   [[ -n "$response" ]] && \
   echo "$response" | jq -e --arg query "$SEARCH_QUERY" '[.[] | select(gsub(" "; "") == gsub(" "; "") | $query)] | any' >/dev/null; then
  echo "$SEARCH_QUERY is a match."
else
  echo "Error: No valid response or $SEARCH_QUERY is not a match."
fi
""",

    
"""
#!/bin/bash
SEARCH_QUERY="Knoxville"

# URL-encode the search query using printf
ENCODED_SEARCH_QUERY=$(printf '%s\n' "$SEARCH_QUERY" | jq -sRr @uri)

response=$(curl -s "https://portal.recoil.ise.utk.edu/api/crd/?crd_dms=${SEARCH_QUERY}")
echo "$response" 
""",
    


    
"""
#!/bin/bash
# Define the API URL and transportation mode to check
ENDPOINT_URL="https://portal.recoil.ise.utk.edu/api/crd/crd_mode/"
SEARCH_QUERY="road"

# Query the API and check for response and partial match in one go
if response=$(curl -s "$ENDPOINT_URL") && \
   [[ -n "$response" ]] && \
   echo "$response" | jq -e --arg query "$SEARCH_QUERY" '[.[] | select(gsub(" "; "") == gsub(" "; "") | $query)] | any' >/dev/null; then
  echo "$SEARCH_QUERY is a match."
else
  echo "Error: No valid response or $SEARCH_QUERY is not a match."
fi
""",


"""
#!/bin/bash
SEARCH_QUERY="road"
SEARCH_QUERY2="Knoxville"

# URL-encode the search query using printf
ENCODED_SEARCH_QUERY=$(printf '%s\n' "$SEARCH_QUERY" | jq -sRr @uri)
ENCODED_SEARCH_QUERY2=$(printf '%s\n' "$SEARCH_QUERY2" | jq -sRr @uri)

# Make sure to use the encoded search query in the curl request
response=$(curl -s "https://portal.recoil.ise.utk.edu/api/crd/?crd_dms=${ENCODED_SEARCH_QUERY2}&crd_dms_mode=${ENCODED_SEARCH_QUERY}")
echo "$response"
""",


    
"""
#!/bin/bash
# Define the API URL and transportation mode to check
ENDPOINT_URL="https://portal.recoil.ise.utk.edu/api/lca/transportation_mode/"
SEARCH_QUERY="Road"

# Query the API and check for response and partial match
if response=$(curl -s "$ENDPOINT_URL") && \
   [[ -n "$response" ]] && \
   echo "$response" | jq -e --arg query "$SEARCH_QUERY" '[.[] | select(gsub(" "; "") == gsub(" "; "") | $query)] | any' >/dev/null; then
  echo "$SEARCH_QUERY is a transportation mode."
else
  echo "Error: No valid response or $SEARCH_QUERY is not a match.. Please select a different mode."
fi
""",


    
"""
#!/bin/bash
# Define the API URL and vehicle type to check
ENDPOINT_URL="https://portal.recoil.ise.utk.edu/api/lca/vehicle_type/"
SEARCH_QUERY="Long_Haul Trucks"

# Query the API and check for response and match
if response=$(curl -s "$ENDPOINT_URL") && \
   [[ -n "$response" ]] && \
   echo "$response" | jq -e --arg query "$SEARCH_QUERY" '[.[] | select(gsub(" "; "") == gsub(" "; "") | $query)] | any' >/dev/null; then
  echo "$SEARCH_QUERY is a match."
else
  echo "Error: No valid response or $SEARCH_QUERY is not a vehicle type."
fi
""",
 
    
"""
#!/bin/bash
SEARCH_QUERY="Long_Haul Trucks"
SEARCH_QUERY2="Road"

# URL-encode the parameters using printf
ENCODED_SEARCH_QUERY=$(printf '%s\n' "$SEARCH_QUERY" | jq -sRr @uri)
ENCODED_SEARCH_QUERY2=$(printf '%s\n' "$SEARCH_QUERY2" | jq -sRr @uri)

# Use double quotes to allow variable expansion
response=$(curl -s "https://portal.recoil.ise.utk.edu/api/lca/?lca_vehicle_type=${ENCODED_SEARCH_QUERY}&lca_transportation_mode=${ENCODED_SEARCH_QUERY2}")
echo "$response"
""",



"""
#!/bin/bash
# Define the API URL and search term to check
ENDPOINT_URL="https://portal.recoil.ise.utk.edu/api/lca/fuel_type/"
SEARCH_QUERY="Conventional and LS Diesel"

# Query the API and check for response and match
if response=$(curl -s "$ENDPOINT_URL") && \
   [[ -n "$response" ]] && \
   echo "$response" | jq -e --arg query "$SEARCH_QUERY" '[.[] | select(gsub(" "; "") == gsub(" "; "") | $query)] | any' >/dev/null; then
  echo "$SEARCH_QUERY is a fuel type."
else
  echo "Error: No valid response or $SEARCH_QUERY is not a match type."
fi
""",



    
"""
#!/bin/bash
SEARCH_QUERY="Long_Haul Trucks"
SEARCH_QUERY2="Road"
SEARCH_QUERY3="Conventional and LS Diesel"

# URL-encode the parameters using printf
ENCODED_SEARCH_QUERY=$(printf '%s\n' "$SEARCH_QUERY" | jq -sRr @uri)
ENCODED_SEARCH_QUERY2=$(printf '%s\n' "$SEARCH_QUERY2" | jq -sRr @uri)
ENCODED_SEARCH_QUERY3=$(printf '%s\n' "$SEARCH_QUERY3" | jq -sRr @uri)

# Use double quotes for variable expansion in the URL
response=$(curl -s "https://portal.recoil.ise.utk.edu/api/lca/?lca_vehicle_type=${ENCODED_SEARCH_QUERY}&lca_transportation_mode=${ENCODED_SEARCH_QUERY2}&lca_fuel_type=${ENCODED_SEARCH_QUERY3}")
echo "$response"
""",


"""
#!/bin/sh

# JSON input
JSON='[
    {"id":1,"lca_vehicle_type":"Long_Haul Trucks","lca_transportation_mode":"Road","lca_fuel_type":"Conventional and LS Diesel","lca_co_2_emission":1583.05,"lca_emission_unit":"g/miles"},
    {"id":2,"lca_vehicle_type":"Long_Haul Trucks","lca_transportation_mode":"Road","lca_fuel_type":"Any","lca_co_2_emission":1317.90,"lca_emission_unit":"g/miles"},
    {"id":3,"lca_vehicle_type":"Long_Haul Trucks","lca_transportation_mode":"Road","lca_fuel_type":"LNG","lca_co_2_emission":1284.57,"lca_emission_unit":"g/miles"},
    {"id":4,"lca_vehicle_type":"Long_Haul Trucks","lca_transportation_mode":"Road","lca_fuel_type":"Electricity","lca_co_2_emission":1171.90,"lca_emission_unit":"g/miles"}
]'
# Distance to calculate emissions for
DISTANCE=900

# Process each JSON object
echo "$JSON" | jq -c '.[]' | while read -r item; do
    # Extract CO2 emission
    co2_emission=$(echo "$item" | jq -r '.lca_co_2_emission')

    # Calculate total emissions
    total_emission=$(echo "$co2_emission * $DISTANCE" | bc)

    # Print total CO2 emissions
    echo "$total_emission"
done
    """
                    ]
# Out:
# [{'instruction': 'If you are an expert in sh script and curl query creation, please generate the logic and queries needed to answer the following question.', 'input': '\n    Check if Atlanta is an hub that belong to the endpoint CRD [output sh code].\n    \n    Execute the query curl -X GET https://portal.recoil.ise.utk.edu/api/crd/?crd_dms=Atlanta this queries the attributes of the location <location name>? [output sh code].\n    ', 'output': ' \n#!/bin/bash\n\n# Query the API and store the response\nresponse=$(curl -s "https://portal.recoil.ise.utk.edu/api/crd/crd_dms/")\n\n# Check if the response is empty\nif [[ -z "$response" ]]; then\n  echo "Error: No response from the API."\n  exit 1\nfi\n# Check if the response is a valid JSON array\nif echo "$response" | jq -e . >/dev/null 2>&1; then\n  # Check if "Atlanta" is present in the response array\n  if echo "$response" | jq -e \'index("Atlanta")\' >/dev/null 2>&1; then\n    echo "Atlanta is an origin hub."\n  else\n    echo "Atlant
# ...

# %%
bank_renege2=[]

# %%
# Define the data for the objects with added text for description
# Define lists for different parameters
locations = ["Pittsburgh PA","Birmingham AL","Houston TX","Washington DC","Bismarck ND","Tulsa OK","Rochester NY","Sacramento CA","Corpus Christi TX","Baltimore MD","Buffalo NY","New York NY","Wyoming","Charleston WV","Indianapolis IN","New Orleans LA","New York PA","Charleston SC","Atlanta GA","Boise ID","Dallas TX","Baton Rouge LA","El Paso TX","Jackson MS","Lake Charles LA","Denver CO","Memphis TN","Milwaukee WI","Tucson AZ","Boston MA","Louisville KY","Savannah GA","Phoenix AZ","Chicago IN","Mobile AL","Iowa","Norfolk VA","Salt Lake City UT","Boston NH","Dayton OH","Cincinnati OH","Greenville SC","Jacksonville FL","Orlando FL","Laredo TX","Grand Rapids MI","Knoxville TN","Hartford CT","Cleveland OH"]
modes = ["Road", "Rail", "Water"]
vehicle_types = ["Long_Haul Trucks ","Any","Freight","Short_Haul Trucks"]
fuel_types = ["HFO (2.7% sulfur)","Diesel","Marine biooil, CFP-Pt/TiO2 (biomass)""FT-Diesel (Biomass&NG)","LNG","Ammonia (Natural Gas)","FT-Diesel (Biomass)","Renewable diesel (Yellow grease&HFO)","MDO (1.92% sulfur )","Liquefied Natural Gas (LNG)","MDO (0.1% sulfur)","Renewable Gasoline","LPG","Marine biocrude, HTL-partially upgraded (Sludge)","eFT Fuelw/ H2 Recycling)","FT-Diesel (Biomass&Coal)","Renewable Diesel II","Marine biooil, FP (biomass)","Ammonia from RNG","MDO (0.5% sulfur)","E-Ammonia (H2 from water electrolysis: PEM)","Methanol (Flare Gas)","MGO (0.5 % sulfur)","Any","DME","MGO (0.1 % sulfur)","HFO (0.1% sulfur)","Pyrolysis oil (Woody biomass)","Straight Vegetable Oil (SVO)","Methanol (Biomass)","MGO (1.0% sulfur)","Ammonia (H2 from Coal Gasification w/ CCS)","FTD","CNG","Electricity","Methanol (Renewable Natural Gas)"]
distances = [100, 200, 300, 345, 500, 342, 543]
emissions = [1583.05, 1317.90, 1284.57, 1501.23, 1456.98, 1304.56, 1559.43, 1347.76, 1189.45]

descriptions = []

# Generate combinations for each process script
for location in locations:
    for mode in modes:
        for vehicle in vehicle_types:
            for fuel in fuel_types:
                for distance in distances:
                    for emission in emissions:
                        descriptions.append(
                            f"""
                            Check if {location} is a hub that belongs to the endpoint CRD [output sh code].
                            """,
                        )
                        descriptions.append(
                            f"""
                            Execute the query curl -X GET https://portal.recoil.ise.utk.edu/api/crd/?crd_dms={location} this queries the attributes of the location {location}? [output sh code].
                            """,
                        )
                        descriptions.append(
                            f"""
                            Check if {mode} is a transportation mode that belongs to the endpoint CRD [output sh code].
                            """,
                        )
                        descriptions.append(
                            f"""
                            Execute the query curl -X GET https://portal.recoil.ise.utk.edu/api/crd/?crd_dms={location}&crd_mode={mode.lower()} this queries the attributes of the Hub based on {location} and mode {mode.lower()}? [output sh code].
                            """,
                        )
                        descriptions.append(
                            f"""
                            Check if {mode} represents a transportation mode that belongs to the endpoint LCA [output sh code].
                            """,
                        )
                        descriptions.append(
                            f"""
                            Check if {vehicle} represents a vehicle type that belongs to the endpoint LCA [output sh code].
                            """,
                        )
                        descriptions.append(
                            f"""
                            Execute the query curl -X GET https://portal.recoil.ise.utk.edu/api/lca/?lca_vehicle_type={vehicle.replace(" ", "%20")}&lca_transportation_mode={mode.lower()} this queries the attributes of the life cycle analysis based on vehicle type {vehicle} and transportation mode {mode.lower()}? [output sh code].
                            """,
                        )
                        descriptions.append(
                            f"""
                            Check if {fuel} represents a fuel type that belongs to the endpoint LCA [output sh code].
                            """,
                        )
                        descriptions.append(
                            f"""
                            Execute the query curl -X GET https://portal.recoil.ise.utk.edu/api/lca/?lca_vehicle_type={vehicle.replace(" ", "%20")}&lca_transportation_mode={mode.lower()}&lca_fuel_type={fuel.replace(" ", "+")} this queries the attributes of the life cycle analysis based on vehicle type {vehicle}, transportation mode {mode.lower()}, and fuel type {fuel}? [output sh code].
                            """,
                        )
                        descriptions.append(
                            f"""
                            Use the output and multiply the [{{"id":1,"lca_vehicle_type":"{vehicle}","lca_transportation_mode":"{mode}","lca_fuel_type":"{fuel}","lca_co_2_emission":{emission},"lca_emission_unit":"g/miles"}}] by {distance} miles considering the different units [output sh code].
                            """
                        )


# Define the process structure
process_structure = []

# Generate combinations for each process script
for location in locations:
    for mode in modes:
        for vehicle in vehicle_types:
            for fuel in fuel_types:
                for distance in distances:
                    for emission in emissions:
                        process_structure.append(f"""
                        #!/bin/bash
                        SEARCH_QUERY="{location}"
                        ENDPOINT_URL="https://portal.recoil.ise.utk.edu/api/crd/crd_dms/"
                        if response=$(curl -s "$ENDPOINT_URL") && \
                           [[ -n "$response" ]] && \
                           echo "$response" | jq -e --arg query "$SEARCH_QUERY" '[.[] | select(gsub(" "; "") == gsub(" "; "") | $query)] | any' >/dev/null; then
                          echo "$SEARCH_QUERY is a match."
                        else
                          echo "Error: No valid response or $SEARCH_QUERY is not a match."
                        fi
                        """)
    
                        process_structure.append(f"""
                        #!/bin/bash
                        SEARCH_QUERY="{location}"
                        response=$(curl -s "https://portal.recoil.ise.utk.edu/api/crd/?crd_dms=${{SEARCH_QUERY}}")
                        echo "$response"
                        """)
    
                        process_structure.append(f"""
                        #!/bin/bash
                        ENDPOINT_URL="https://portal.recoil.ise.utk.edu/api/crd/crd_mode/"
                        SEARCH_QUERY="{mode}"
                        if response=$(curl -s "$ENDPOINT_URL") && \
                           [[ -n "$response" ]] && \
                           echo "$response" | jq -e --arg query "$SEARCH_QUERY" '[.[] | select(gsub(" "; "") == gsub(" "; "") | $query)] | any' >/dev/null; then
                          echo "$SEARCH_QUERY is a match."
                        else
                          echo "Error: No valid response or $SEARCH_QUERY is not a match."
                        fi
                        """)
    
                        process_structure.append(f"""
                        #!/bin/bash
                        SEARCH_QUERY="{mode}"
                        SEARCH_QUERY2="{location}"
                        response=$(curl -s "https://portal.recoil.ise.utk.edu/api/crd/?crd_dms=${{SEARCH_QUERY2}}&crd_dms_mode=${{SEARCH_QUERY}}")
                        echo "$response"
                        """)
    
                        process_structure.append(f"""
                        #!/bin/bash
                        ENDPOINT_URL="https://portal.recoil.ise.utk.edu/api/lca/transportation_mode/"
                        SEARCH_QUERY="{mode}"
                        if response=$(curl -s "$ENDPOINT_URL") && \
                           [[ -n "$response" ]] && \
                           echo "$response" | jq -e --arg query "$SEARCH_QUERY" '[.[] | select(gsub(" "; "") == gsub(" "; "") | $query)] | any' >/dev/null; then
                          echo "$SEARCH_QUERY is a transportation mode."
                        else
                          echo "Error: No valid response or $SEARCH_QUERY is not a match."
                        fi
                        """)
    
                        process_structure.append(f"""
                        #!/bin/bash
                        ENDPOINT_URL="https://portal.recoil.ise.utk.edu/api/lca/vehicle_type/"
                        SEARCH_QUERY="{vehicle}"
                        if response=$(curl -s "$ENDPOINT_URL") && \
                           [[ -n "$response" ]] && \
                           echo "$response" | jq -e --arg query "$SEARCH_QUERY" '[.[] | select(gsub(" "; "") == gsub(" "; "") | $query)] | any' >/dev/null; then
                          echo "$SEARCH_QUERY is a vehicle type."
                        else
                          echo "Error: No valid response or $SEARCH_QUERY is not a vehicle type."
                        fi
                        """)
    
                        process_structure.append(f"""
                        #!/bin/bash
                        SEARCH_QUERY="{vehicle}"
                        SEARCH_QUERY2="{mode}"
                        response=$(curl -s "https://portal.recoil.ise.utk.edu/api/lca/?lca_vehicle_type=${{SEARCH_QUERY}}&lca_transportation_mode=${{SEARCH_QUERY2}}")
                        echo "$response"
                        """)
    
                        process_structure.append(f"""
                        #!/bin/bash
                        ENDPOINT_URL="https://portal.recoil.ise.utk.edu/api/lca/fuel_type/"
                        SEARCH_QUERY="{fuel}"
                        if response=$(curl -s "$ENDPOINT_URL") && \
                           [[ -n "$response" ]] && \
                           echo "$response" | jq -e --arg query "$SEARCH_QUERY" '[.[] | select(gsub(" "; "") == gsub(" "; "") | $query)] | any' >/dev/null; then
                          echo "$SEARCH_QUERY is a fuel type."
                        else
                          echo "Error: No valid response or $SEARCH_QUERY is not a match type."
                        fi
                        """)
    
                        process_structure.append(f"""
                        #!/bin/bash
                        SEARCH_QUERY="{vehicle}"
                        SEARCH_QUERY2="{mode}"
                        SEARCH_QUERY3="{fuel}"
    
                        response=$(curl -s "https://portal.recoil.ise.utk.edu/api/lca/?lca_vehicle_type=${{SEARCH_QUERY}}&lca_transportation_mode=${{SEARCH_QUERY2}}&lca_fuel_type=${{SEARCH_QUERY3}}")
                        echo "$response"
                        """)

                        process_structure.append(f"""
                        #!/bin/sh
                        # Prepare JSON input for emissions calculation
                        JSON='[
                            {{"id":1,"lca_vehicle_type":"{vehicle}","lca_transportation_mode":"{mode}","lca_fuel_type":"{fuel}","lca_co_2_emission":{emission},"lca_emission_unit":"g/miles"}},
                            {{"id":2,"lca_vehicle_type":"{vehicle}","lca_transportation_mode":"{mode}","lca_fuel_type":"{fuel}","lca_co_2_emission":{emission},"lca_emission_unit":"g/miles"}},
                            {{"id":3,"lca_vehicle_type":"{vehicle}","lca_transportation_mode":"{mode}","lca_fuel_type":"{fuel}","lca_co_2_emission":{emission},"lca_emission_unit":"g/miles"}},
                            {{"id":4,"lca_vehicle_type":"{vehicle}","lca_transportation_mode":"{mode}","lca_fuel_type":"{fuel}","lca_co_2_emission":{emission},"lca_emission_unit":"g/miles"}}
                        ]'
                        # Calculate emissions for the distance
                        DISTANCE={distance}
                        echo "Calculating emissions for a distance of $DISTANCE miles..."
                        # Extract and calculate total emissions
                        total_emissions=0
                        # Loop through JSON data
                        for row in $(echo "$JSON" | jq -c '.[]'); do
                            emission=$(echo "$row" | jq -r '.lca_co_2_emission')
                            total_emissions=$(echo "$total_emissions + (${emission} * $DISTANCE)" | bc)
                        done
                        echo "Total CO2 emissions for ${distance} miles: $total_emissions g"
                        """)
    
             

# Output all generated process scripts
# for script in process_structure:
#     print(script)

# %%
# Loop over the descriptions to create the object list
for ds,ps in zip(descriptions,process_structure):
    obj = {
        "instruction": "If you are an expert in sh script and curl query creation, please generate the logic and queries needed to answer the following question.",
        "input": str(ds),
        "output": str(ps)
    }
    bank_renege2.append(obj)

# Print or use the list of objects
print(bank_renege2[0])
# Out:
# {'instruction': 'If you are an expert in sh script and curl query creation, please generate the logic and queries needed to answer the following question.', 'input': '\n                            Check if Pittsburgh PA is a hub that belongs to the endpoint CRD [output sh code].\n                            ', 'output': '\n                        #!/bin/bash\n                        SEARCH_QUERY="Pittsburgh PA"\n                        ENDPOINT_URL="https://portal.recoil.ise.utk.edu/api/crd/crd_dms/"\n                        if response=$(curl -s "$ENDPOINT_URL") &&                            [[ -n "$response" ]] &&                            echo "$response" | jq -e --arg query "$SEARCH_QUERY" \'[.[] | select(gsub(" "; "") == gsub(" "; "") | $query)] | any\' >/dev/null; then\n                          echo "$SEARCH_QUERY is a match."\n                        else\n                          echo "Error: No valid response or $SEARCH_QUERY is not a match."\n                        fi\n
# ...

# %%
print(bank_renege2[0])
# Out:
# {'instruction': 'If you are an expert in sh script and curl query creation, please generate the logic and queries needed to answer the following question.', 'input': '\n                            Check if Pittsburgh PA is a hub that belongs to the endpoint CRD [output sh code].\n                            ', 'output': '\n                        #!/bin/bash\n                        SEARCH_QUERY="Pittsburgh PA"\n                        ENDPOINT_URL="https://portal.recoil.ise.utk.edu/api/crd/crd_dms/"\n                        if response=$(curl -s "$ENDPOINT_URL") &&                            [[ -n "$response" ]] &&                            echo "$response" | jq -e --arg query "$SEARCH_QUERY" \'[.[] | select(gsub(" "; "") == gsub(" "; "") | $query)] | any\' >/dev/null; then\n                          echo "$SEARCH_QUERY is a match."\n                        else\n                          echo "Error: No valid response or $SEARCH_QUERY is not a match."\n                        fi\n
# ...

# %%
# Flatten the lists of dictionaries into a single list
all_data = bank_renege2 

# Create a DataFrame from the flattened list
df = pd.DataFrame(all_data)

# Show the DataFrame
print(df.shape)
# Out:
# (25930800, 3)

# %%
df=df.sample(1000)
df.reset_index(inplace=True)
df=df.drop(columns=['index'])

# %%
pd.set_option('display.max_colwidth', None)

# %%
df
# Out:
#                                                                                                                                    instruction  \
# 0    If you are an expert in sh script and curl query creation, please generate the logic and queries needed to answer the following question.
# 1    If you are an expert in sh script and curl query creation, please generate the logic and queries needed to answer the following question.
# 2    If you are an expert in sh script and curl query creation, please generate the logic and queries needed to answer the following question.
# 3    If you are an expert in sh script and curl query creation, please generate the logic and queries needed to answer the following question.
# 4    If you are an expert in sh script and curl query creation, please generate the logic and queries needed to answer the following question.
# ...

# %%
df.to_csv('fintuning/train-edited.csv',index=False)

# %%
# Step 3: Save the edited DataFrame back to a Parquet file
output_file_path = 'fintuning/train-edited.parquet'
df.to_parquet(output_file_path,index=False)

print("File saved successfully.")
# Out:
# File saved successfully.
